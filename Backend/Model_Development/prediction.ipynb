# %%
import yfinance as yf
import pandas as pd

# %%
btc_ticker=yf.Ticker('BTC-USD')

# %%
btc=btc_ticker.history(period='max')

# %%
btc
# Out:
#                                    Open          High           Low  \
# Date
# 2014-09-17 00:00:00+00:00    465.864014    468.174011    452.421997
# 2014-09-18 00:00:00+00:00    456.859985    456.859985    413.104004
# 2014-09-19 00:00:00+00:00    424.102997    427.834991    384.532013
# 2014-09-20 00:00:00+00:00    394.673004    423.295990    389.882996
# 2014-09-21 00:00:00+00:00    408.084991    412.425995    393.181000
# ...                                 ...           ...           ...
# 2024-10-22 00:00:00+00:00  67360.703125  67801.578125  66581.367188
# 2024-10-23 00:00:00+00:00  67362.375000  67402.742188  65188.035156
# 2024-10-24 00:00:00+00:00  66653.703125  68798.960938  66454.101562
# 2024-10-25 00:00:00+00:00  68165.296875  68722.156250  65521.792969
# 2024-10-26 00:00:00+00:00  66599.015625  67145.414062  66424.320312
#
#                                   Close       Volume  Dividends  Stock Splits
# Date
# ...

# %%
del btc['Dividends']
del btc['Stock Splits']

# %%
btc.index=pd.to_datetime(btc.index)

# %%
btc.columns=[c.lower() for c in btc.columns]

# %%
btc.head()
# Out:
#                                  open        high         low       close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              volume
# Date
# 2014-09-17 00:00:00+00:00  21056800
# 2014-09-18 00:00:00+00:00  34483200
# 2014-09-19 00:00:00+00:00  37919700
# 2014-09-20 00:00:00+00:00  36863600
# 2014-09-21 00:00:00+00:00  26580100

# %%
btc.index=btc.index.normalize()

# %%
btc.head()
# Out:
#                                  open        high         low       close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              volume
# Date
# 2014-09-17 00:00:00+00:00  21056800
# 2014-09-18 00:00:00+00:00  34483200
# 2014-09-19 00:00:00+00:00  37919700
# 2014-09-20 00:00:00+00:00  36863600
# 2014-09-21 00:00:00+00:00  26580100

# %%
btc.index = btc.index.strftime('%Y-%m-%d')

# %%
btc.head()
# Out:
#                   open        high         low       close    volume
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100

# %%
btc.index.dtype
# Out:
# dtype('O')

# %%
btc.index=pd.to_datetime(btc.index)

# %%
btc.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
btc.head()
# Out:
#                   open        high         low       close    volume
# Date
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100

# %%
import matplotlib.pyplot as plt
btc.plot.line(y='close',use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
wiki=pd.read_csv('wikipedia.csv',index_col=0,parse_dates=True)

# %%
wiki
# Out:
#             edit_count  sentiment-mean  neg-sentiment
# 2009-09-03    0.500000       -0.043812       0.086508
# 2009-09-04    0.500000       -0.043812       0.086508
# 2009-09-05    0.500000       -0.043812       0.086508
# 2009-09-06    0.500000       -0.043812       0.086508
# 2009-09-07    0.500000       -0.043812       0.086508
# ...                ...             ...            ...
# 2024-10-22    1.066667       -0.190901       0.244872
# 2024-10-23    1.133333       -0.219141       0.278205
# 2024-10-24    1.133333       -0.219141       0.278205
# 2024-10-25    1.133333       -0.219141       0.278205
# 2024-10-26    1.133333       -0.219141       0.278205
#
# [5533 rows x 3 columns]

# %%
btc.shape
# Out:
# (3693, 5)

# %%
btc=btc.merge(wiki,left_index=True,right_index=True)

# %%
btc
# Out:
#                     open          high           low         close  \
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2024-10-22  67360.703125  67801.578125  66581.367188  67361.406250
# 2024-10-23  67362.375000  67402.742188  65188.035156  66432.195312
# 2024-10-24  66653.703125  68798.960938  66454.101562  68161.054688
# 2024-10-25  68165.296875  68722.156250  65521.792969  66642.414062
# 2024-10-26  66599.015625  67145.414062  66424.320312  66987.632812
#
#                  volume  edit_count  sentiment-mean  neg-sentiment
# 2014-09-17     21056800    0.533333       -0.109741       0.154444
# ...

# %%
btc['tomorrow']=btc['close'].shift(-1)

# %%
btc.head()
# Out:
#                   open        high         low       close    volume  \
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100
#
#             edit_count  sentiment-mean  neg-sentiment    tomorrow
# 2014-09-17    0.533333       -0.109741       0.154444  424.440002
# 2014-09-18    0.566667       -0.142785       0.187778  394.795990
# 2014-09-19    0.600000       -0.176097       0.221111  408.903992
# 2014-09-20    0.600000       -0.176097       0.221111  398.821014
# 2014-09-21    0.600000       -0.109894       0.187778  402.152008

# %%
btc['target']=(btc['tomorrow']>btc['close']).astype(int)

# %%
btc.head()
# Out:
#                   open        high         low       close    volume  \
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
# 2014-09-18  456.859985  456.859985  413.104004  424.440002  34483200
# 2014-09-19  424.102997  427.834991  384.532013  394.795990  37919700
# 2014-09-20  394.673004  423.295990  389.882996  408.903992  36863600
# 2014-09-21  408.084991  412.425995  393.181000  398.821014  26580100
#
#             edit_count  sentiment-mean  neg-sentiment    tomorrow  target
# 2014-09-17    0.533333       -0.109741       0.154444  424.440002       0
# 2014-09-18    0.566667       -0.142785       0.187778  394.795990       0
# 2014-09-19    0.600000       -0.176097       0.221111  408.903992       1
# 2014-09-20    0.600000       -0.176097       0.221111  398.821014       0
# 2014-09-21    0.600000       -0.109894       0.187778  402.152008       1

# %%
btc['target'].value_counts()
# Out:
# target
# 1    1951
# 0    1742
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=100,min_samples_split=50,random_state=1)

# %%
train=btc[:-200]
test=btc[-200:]

# %%
btc.head(1)
# Out:
#                   open        high         low       close    volume  \
# 2014-09-17  465.864014  468.174011  452.421997  457.334015  21056800
#
#             edit_count  sentiment-mean  neg-sentiment    tomorrow  target
# 2014-09-17    0.533333       -0.109741       0.154444  424.440002       0

# %%
predictors=['open','high','low','close','volume','edit_count','sentiment-mean','neg-sentiment']
model.fit(train[predictors],train['target'])
# Out:
# RandomForestClassifier(min_samples_split=50, random_state=1)

# %%
import pickle

pickle.dump(model,open('pickle_files/rf_model.pkl','wb'))

# %%
from sklearn.metrics import precision_score

preds=model.predict(test[predictors])
precision_score(preds,test['target'].values)
# Out:
# np.float64(0.3917525773195876)

# %%
def predict(train,test,predictors,model):
    model.fit(train[predictors],train['target'])
    preds=model.predict(test[predictors])
    preds=pd.Series(preds,index=test.index,name='predictions')
    combined=pd.concat([test['target'],preds],axis=1)
    return combined

# %%
def backtest(data,model,predictors,start=1095,step=150):
    all_predictions=[]
    for i in range(start,data.shape[0],step):
        train=data[0:i].copy()
        test=data[i:(i+step)].copy()
        predictions=predict(train,test,predictors,model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier(random_state=1,learning_rate=0.1,n_estimators=200)

# %%
predictions=backtest(btc,model,predictors)

# %%
predictions.head()
# Out:
#             target  predictions
# 2017-09-16       0            0
# 2017-09-17       1            0
# 2017-09-18       0            1
# 2017-09-19       0            0
# 2017-09-20       0            0

# %%
precision_score(predictions['target'],predictions['predictions'])
# Out:
# np.float64(0.5227817745803357)
